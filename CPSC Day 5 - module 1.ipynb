# %%
import pandas as pd

# %%
df = pd.read_csv(r"zomato.csv", encoding="Latin1")

# %%
new = df[["Restaurant Name","City"]]

# %%
new.to_excel("myfile.xlsx")

# %%
df.columns
# 1. What is the highest 'Aggregate rating'
# 2. How many rests have the highest rating
df_highest = df[df["Aggregate rating"] == df["Aggregate rating"].max()]
df_highest_n = df_highest["Restaurant ID"].count()
df_highest_n
# Out:
# 61

# %%
ratings = df["Aggregate rating"].value_counts()
ratings.loc[ratings.index.max()]
# Out:
# 61

# %%
ratings.loc[ratings.index.min()]
# dir(ratings.index)
# Out:
# 2148

# %%
df["Aggregate rating"].value_counts(True)
# Out:
# Aggregate rating
# 0.0    0.224898
# 3.2    0.054654
# 3.1    0.054340
# 3.4    0.052141
# 3.3    0.050571
# 3.5    0.050257
# 3.0    0.049000
# 3.6    0.047953
# 3.7    0.044707
# 3.8    0.041880
# 2.9    0.039891
# 3.9    0.035075
# 2.8    0.032981
# 4.1    0.028688
# 4.0    0.027850
# 2.7    0.026175
# 4.2    0.023139
# 2.6    0.019998
# 4.3    0.018218
# 4.4    0.015077
# 2.5    0.011517
# 4.5    0.009947
# 2.4    0.009109
# 4.6    0.008167
# 4.9    0.006387
# 2.3    0.004921
# 4.7    0.004397
# 2.2    0.002827
# 4.8    0.002618
# 2.1    0.001571
# 2.0    0.000733
# 1.9    0.000209
# 1.8    0.000105
# Name: proportion, dtype: float64

# %%
ratings_gb = df.groupby("Aggregate rating")["Restaurant ID"].count()
ratings_gb.loc[ratings_gb.index.max()]
# Out:
# 61

# %%
# How many unique cities are in the data set
ncities=df["City"].nunique()
ncities
# Out:
# 141

# %%
# How many rests are in New Delhi
count = df[df['City'] == 'New Delhi'].count().iloc[0]
count
# Out:
# 5473

# %%
cities = df["City"].value_counts()
cities.loc["New Delhi"]
# Out:
# 5473

# %%
cities.to_frame()
# Out:
#                   count
# City
# New Delhi          5473
# Gurgaon            1118
# Noida              1080
# Faridabad           251
# Ghaziabad            25
# ...                 ...
# Panchkula             1
# Mc Millan             1
# Mayfield              1
# Macedon               1
# Vineland Station      1
#
# [141 rows x 1 columns]

# %%
cities_gb= df.groupby("City")[["Restaurant ID"]].count()
cities_gb.loc["New Delhi"]
# Out:
# Restaurant ID    5473
# Name: New Delhi, dtype: int64

# %%
cities_gb.reset_index(inplace=True)

# %%
cities_gb.to_excel("ListRest.xlsx")
# Out:
#                 City  Restaurant ID
# 0          Abu Dhabi             20
# 1               Agra             20
# 2          Ahmedabad             21
# 3             Albany             20
# 4          Allahabad             20
# ..               ...            ...
# 136          Weirton              1
# 137  Wellington City             20
# 138   Winchester Bay              1
# 139          Yorkton              1
# 140        ÛÁstanbul             14
#
# [141 rows x 2 columns]

# %%
cn = df["Cuisines"].str.contains("Chinese").sum()

us = df["Cuisines"].str.contains("American").sum()

print(f"Chinese: {cn}", f"American: {us}")
# Out:
# Chinese: 2733 American: 405

# %%
# Get all Chinese rest in New Delhi
cond1 = df["Cuisines"].str.contains("Chinese",   case=False)
cond2 = df["City"]=="New Delhi"
cnl = df[cond1 & cond2][["Restaurant Name","City","Cuisines"]]

# %%
nd = df[df["City"]=="New Delhi"]
nd_chi = nd[ nd["Cuisines"].str.contains("Chinese", case=False)]
nd_chi
# Out:
#       Restaurant ID    Restaurant Name  Country Code       City  \
# 2564            582          Govardhan             1  New Delhi
# 2569            948              Waves             1  New Delhi
# 2570           2853       Delhi Darbar             1  New Delhi
# 2577         308235           Sultanat             1  New Delhi
# 2579         307383    Clever Fox Cafe             1  New Delhi
# ...             ...                ...           ...        ...
# 8001       18175274        Momos House             1  New Delhi
# 8003           2605  Rhythm Restro-Bar             1  New Delhi
# 8009            954          Karnataka             1  New Delhi
# 8020       18349925        Al-Kausar's             1  New Delhi
# 8029       18168147     S.K. Fast Food             1  New Delhi
#
#                                                 Address  \
# 2564  84, Adjacent Hero Motor Bike Showroom, Main Me...
# 2569         A-4, Sarvodaya Enclave, Adchini, New Delhi
# ...

# %%
df.columns
# Based on 'Average Cost for two' find most expensive rests
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
cond_av= df["Average Cost for two"]==df["Average Cost for two"].max()
df[cond_av][[ 'Restaurant Name', 'Restaurant ID', 'Average Cost for two', 'Aggregate rating']]
# Out:
#                Restaurant Name  Restaurant ID  Average Cost for two  \
# 9283                      Skye        7402935                800000
# 9284  Satoo - Hotel Shangri-La        7410290                800000
#
#       Aggregate rating
# 9283               4.1
# 9284               4.6

# %%
# Find most expensive chinese rstaturants in New Delhi
is_chinese = df["Cuisines"].str.contains("Chinese", case=False, na=False)
in_new_delhi = df["City"] == "New Delhi"
nd_ch = df[is_chinese & in_new_delhi]
nd_ch[nd_ch["Average Cost for two"] == nd_ch["Average Cost for two"].max()][["Restaurant Name", "Cuisines", "Average Cost for two"]]
# Out:
#                                Restaurant Name  \
# 4088  Tian - Asian Cuisine Studio - ITC Maurya
#
#                                     Cuisines  Average Cost for two
# 4088  Asian, Japanese, Korean, Thai, Chinese                  7000

# %%
nd = df[df["City"]=="New Delhi"]
nd_chi = nd[ nd["Cuisines"].str.contains("Chinese", case=False)]
r = nd_chi[nd_chi["Average Cost for two"] == nd_chi["Average Cost for two"].max()]
r[["Restaurant Name", "Cuisines", "Average Cost for two"]]
# Out:
#                                Restaurant Name  \
# 4088  Tian - Asian Cuisine Studio - ITC Maurya
#
#                                     Cuisines  Average Cost for two
# 4088  Asian, Japanese, Korean, Thai, Chinese                  7000

# %%
city = "New Delhi"
df.query("City == @city")
df.query("City == 'New Delhi' ")
# Out:
#       Restaurant ID       Restaurant Name  Country Code       City  \
# 2560       18287358            Food Cloud             1  New Delhi
# 2561       18216944             Burger.in             1  New Delhi
# 2562         313333       Days of the Raj             1  New Delhi
# 2563       18384127        Dilli Ka Dhaba             1  New Delhi
# 2564            582             Govardhan             1  New Delhi
# ...             ...                   ...           ...        ...
# 8028       18445274          Motu N Patlu             1  New Delhi
# 8029       18168147        S.K. Fast Food             1  New Delhi
# 8030       18429375    Sufiyan Restaurant             1  New Delhi
# 8031         310479       The Relax Point             1  New Delhi
# 8032       18212160  Zareen's Dastarkhwan             1  New Delhi
#
#                                                 Address     Locality  \
# 2560                              Aaya Nagar, New Delhi   Aaya Nagar
# ...

# %%
cities = ['Clatskanie', 'Cochrane', 'Columbus', 'Consort', 'Dalton',
       'Davenport', 'Des Moines']

# %%
df.query(" Cuisines in 'Chinese' and City in @cities ")
# Out:
#      Restaurant ID               Restaurant Name  Country Code        City  \
# 199       17330087  Chef Lee's Peking Restaurant           216    Columbus
# 241       17334718                    China Cafe           216   Davenport
# 263       17259166              Tsing Tsao South           216  Des Moines
#
#                                       Address            Locality  \
# 199  6100 Bradley Park Dr, Columbus, GA 31904            Columbus
# 241       3018 E 53rd St, Davenport, IA 52807           Davenport
# 263       4230 Fleur Dr, Des Moines, IA 50321  Greater South Side
#
#                    Locality Verbose  Longitude   Latitude Cuisines  ...  \
# 199              Columbus, Columbus -84.960700  32.539300  Chinese  ...
# 241            Davenport, Davenport -90.532100  41.574900  Chinese  ...
# 263  Greater South Side, Des Moines -93.645245  41.545869  Chinese  ...
#
#       Currency Has Table booking Has Online delivery Is delivering now  \
# ...

# %%
df.query("Cuisines.str.contains('Chinese', na=False)", engine='python')
