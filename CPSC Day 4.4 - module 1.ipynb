# %%
numbers = [1,2,3,4,5,5,5,5,5,5]
fives = []

# %%
for value in numbers:
    if value == 5:
        fives.append(value)
fives
# Out:
# [5, 5, 5, 5, 5, 5]

# %%
# [expression for loop filter]

# %%
[value for value in numbers if value == 5]
# Out:
# [5, 5, 5, 5, 5, 5]

# %%
week = ["mon","tue","wed"]
week_cap = [day.capitalize() for day in week]
week_cap
# Out:
# ['Mon', 'Tue', 'Wed']

# %%
string ="a2p7p5l3e4"
# use list com and get the sum of all numbers
sum([ int(char) for char in string if char.isdigit() ])
# Out:
# 21

# %%
numbers = list(range(1,11) )
["even" if x % 2==0 else "odd" for x in numbers]
# Out:
# ['odd', 'even', 'odd', 'even', 'odd', 'even', 'odd', 'even', 'odd', 'even']

# %%
list(map(lambda x: "even" if x % 2==0 else "odd",numbers))
# Out:
# ['odd', 'even', 'odd', 'even', 'odd', 'even', 'odd', 'even', 'odd', 'even']
